# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
#Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
#Import requests
import requests
from config import weather_api_key
#url = "https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={weather_api_key}"

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90, size = 1500)
lngs = np.random.uniform(-90,90, size = 1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#Create a list for holding the ciites
cities = []
#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is uniqe, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 642

# %%
#Create an empty list to hold the weather data
city_data = []
#pring the begining of the logging
print("Beginning Data Retrieval    ")
print("----------------------------")

#Create counters
record_count = 1
set_count =1
# Out:
# Beginning Data Retrieval
# ----------------------------

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
city_url = f"{url}q={city}&appid={weather_api_key}&units=imperial"
city_url
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?q=narsaq&appid=6fcbf74a8746fece74876885d04ba057&units=imperial'

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -46.05, 'lat': 60.9167},
#  'weather': [{'id': 600,
#    'main': 'Snow',
#    'description': 'light snow',
#    'icon': '13n'}],
#  'base': 'stations',
#  'main': {'temp': 33.19,
#   'feels_like': 23.92,
#   'temp_min': 33.19,
#   'temp_max': 33.19,
#   'pressure': 1005,
#   'humidity': 96,
#   'sea_level': 1005,
#   'grnd_level': 1002},
#  'visibility': 475,
#  'wind': {'speed': 12.86, 'deg': 54, 'gust': 16.84},
#  'snow': {'1h': 0.43},
#  'clouds': {'all': 100},
#  'dt': 1651802267,
#  'sys': {'country': 'GL', 'sunrise': 1651733145, 'sunset': 1651792558},
#  'timezone': -7200,
#  'id': 3421719,
#  'name': 'Narsaq',
#  'cod': 200}

# %%
#Loop through all the cities in our list.
for i, city in enumerate(cities):
    time.sleep(1)

    #Group cities in sets of 50 for logging purposes
    if (i%50 == 0 and i>50):
        set_count+=1
        record_count=1
        #time.sleep(60)
        
    #Create endpoint URL with each city.
    
    url = "https://api.openweathermap.org/data/2.5/weather?"
    city_url = f"{url}q={city}&appid={weather_api_key}&units=imperial"
  
   
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 2 | bambous virieux
# Processing Record 2 of Set 2 | iqaluit
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | tsivilsk
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | taltal
# Processing Record 8 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 2 | requena
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | honningsvag
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | sambava
# Processing Record 14 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 2 | san andres
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | namibe
# Processing Record 18 of Set 2 | lima
# Processing Record 19 of Set 2 | akureyri
# Processing Record 20 of Set 2 | mizan teferi
# Processing Record 21 of Set 2 | fasa
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | pimentel
# Processing Record 24 of Set 2 | ostrovnoy
# Processing Record 25 of Set 2 | meridian
# Processing Record 26 of Set 2 | victoria
# Processing Record 27 of Set 2 | mar del plata
# Processing Record 28 of Set 2 | shahpura
# Processing Record 29 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 30 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 2 | hofn
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | awbari
# Processing Record 35 of Set 2 | clyde river
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | east london
# Processing Record 38 of Set 2 | codrington
# Processing Record 39 of Set 2 | gamba
# Processing Record 40 of Set 2 | matara
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | den helder
# Processing Record 43 of Set 2 | bandarbeyla
# Processing Record 44 of Set 2 | longyearbyen
# Processing Record 45 of Set 2 | puerto leguizamo
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | busselton
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 2 | rognan
# Processing Record 51 of Set 2 | kamenka
# Processing Record 52 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 53 of Set 2 | belmonte
# Processing Record 54 of Set 2 | arraial do cabo
# Processing Record 55 of Set 2 | port blair
# Processing Record 56 of Set 2 | kidal
# Processing Record 57 of Set 2 | port elizabeth
# Processing Record 58 of Set 2 | dudinka
# Processing Record 59 of Set 2 | vokhma
# Processing Record 60 of Set 2 | inhambane
# Processing Record 61 of Set 2 | turukhansk
# Processing Record 62 of Set 2 | sao geraldo do araguaia
# Processing Record 63 of Set 2 | vestmannaeyjar
# Processing Record 64 of Set 2 | sangmelima
# Processing Record 65 of Set 2 | hamilton
# Processing Record 66 of Set 2 | bababe
# City not found. Skipping...
# Processing Record 67 of Set 2 | narsaq
# Processing Record 68 of Set 2 | shache
# Processing Record 69 of Set 2 | salalah
# Processing Record 70 of Set 2 | saldanha
# Processing Record 71 of Set 2 | edd
# Processing Record 72 of Set 2 | bredasdorp
# Processing Record 73 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 74 of Set 2 | tromso
# Processing Record 75 of Set 2 | teguldet
# Processing Record 76 of Set 2 | bilma
# Processing Record 77 of Set 2 | chuy
# Processing Record 78 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 79 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 80 of Set 2 | riviere-au-renard
# Processing Record 81 of Set 2 | zhezkazgan
# Processing Record 82 of Set 2 | hithadhoo
# Processing Record 83 of Set 2 | upernavik
# Processing Record 84 of Set 2 | dingle
# Processing Record 85 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 86 of Set 2 | thomaston
# Processing Record 87 of Set 2 | bawku
# Processing Record 88 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 89 of Set 2 | nouadhibou
# Processing Record 90 of Set 2 | santa cruz de tenerife
# Processing Record 91 of Set 2 | rio gallegos
# Processing Record 92 of Set 2 | talara
# Processing Record 93 of Set 2 | cidreira
# Processing Record 94 of Set 2 | berlevag
# Processing Record 95 of Set 2 | mogadishu
# Processing Record 96 of Set 2 | ilulissat
# Processing Record 97 of Set 2 | marechal candido rondon
# Processing Record 98 of Set 2 | paamiut
# Processing Record 99 of Set 2 | aljezur
# Processing Record 100 of Set 2 | hearst
# Processing Record 1 of Set 3 | solwezi
# Processing Record 2 of Set 3 | kindia
# Processing Record 3 of Set 3 | qaanaaq
# Processing Record 4 of Set 3 | eenhana
# Processing Record 5 of Set 3 | kindu
# Processing Record 6 of Set 3 | saint-denis
# Processing Record 7 of Set 3 | hobyo
# Processing Record 8 of Set 3 | yelan-koleno
# Processing Record 9 of Set 3 | zhanaozen
# Processing Record 10 of Set 3 | macusani
# Processing Record 11 of Set 3 | gordeyevka
# Processing Record 12 of Set 3 | mashhad
# Processing Record 13 of Set 3 | saint-augustin
# Processing Record 14 of Set 3 | yenagoa
# Processing Record 15 of Set 3 | grindavik
# Processing Record 16 of Set 3 | lagos
# Processing Record 17 of Set 3 | saint-pierre
# Processing Record 18 of Set 3 | shelburne
# Processing Record 19 of Set 3 | valparaiso
# Processing Record 20 of Set 3 | opuwo
# Processing Record 21 of Set 3 | talcahuano
# Processing Record 22 of Set 3 | faya
# Processing Record 23 of Set 3 | dujuma
# City not found. Skipping...
# Processing Record 24 of Set 3 | jalu
# Processing Record 25 of Set 3 | vagur
# Processing Record 26 of Set 3 | arlit
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | mehamn
# Processing Record 29 of Set 3 | shediac
# Processing Record 30 of Set 3 | olinda
# Processing Record 31 of Set 3 | goderich
# Processing Record 32 of Set 3 | muros
# Processing Record 33 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 3 | jijiga
# Processing Record 35 of Set 3 | eskasem
# City not found. Skipping...
# Processing Record 36 of Set 3 | iracoubo
# Processing Record 37 of Set 3 | saint anthony
# Processing Record 38 of Set 3 | aksehir
# Processing Record 39 of Set 3 | ormara
# Processing Record 40 of Set 3 | saint-philippe
# Processing Record 41 of Set 3 | cairo
# Processing Record 42 of Set 3 | luderitz
# Processing Record 43 of Set 3 | qurayyat
# Processing Record 44 of Set 3 | santa rosa
# Processing Record 45 of Set 3 | nanortalik
# Processing Record 46 of Set 3 | belvedere marittimo
# Processing Record 47 of Set 3 | porto novo
# Processing Record 48 of Set 3 | olavarria
# Processing Record 49 of Set 3 | burica
# City not found. Skipping...
# Processing Record 50 of Set 3 | saint-francois
# Processing Record 1 of Set 4 | saint george
# Processing Record 2 of Set 4 | itarema
# Processing Record 3 of Set 4 | escanaba
# Processing Record 4 of Set 4 | teguise
# Processing Record 5 of Set 4 | nagornskiy
# Processing Record 6 of Set 4 | garowe
# Processing Record 7 of Set 4 | cabanas
# Processing Record 8 of Set 4 | pau brasil
# Processing Record 9 of Set 4 | laureles
# Processing Record 10 of Set 4 | najran
# Processing Record 11 of Set 4 | pretoria
# Processing Record 12 of Set 4 | necochea
# Processing Record 13 of Set 4 | empangeni
# Processing Record 14 of Set 4 | ferkessedougou
# Processing Record 15 of Set 4 | aguimes
# Processing Record 16 of Set 4 | kajaani
# Processing Record 17 of Set 4 | padang
# Processing Record 18 of Set 4 | le port
# Processing Record 19 of Set 4 | pokhara
# Processing Record 20 of Set 4 | sassandra
# Processing Record 21 of Set 4 | syedove
# Processing Record 22 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 4 | bulawayo
# Processing Record 24 of Set 4 | tasiilaq
# Processing Record 25 of Set 4 | sao filipe
# Processing Record 26 of Set 4 | sisimiut
# Processing Record 27 of Set 4 | pisco
# Processing Record 28 of Set 4 | razlog
# Processing Record 29 of Set 4 | buenos aires
# Processing Record 30 of Set 4 | cusset
# Processing Record 31 of Set 4 | novoagansk
# Processing Record 32 of Set 4 | kusk
# City not found. Skipping...
# Processing Record 33 of Set 4 | visby
# Processing Record 34 of Set 4 | geraldton
# Processing Record 35 of Set 4 | cap-aux-meules
# Processing Record 36 of Set 4 | aripuana
# Processing Record 37 of Set 4 | maldonado
# Processing Record 38 of Set 4 | bonavista
# Processing Record 39 of Set 4 | bideford
# Processing Record 40 of Set 4 | mahebourg
# Processing Record 41 of Set 4 | nizwa
# Processing Record 42 of Set 4 | klaksvik
# Processing Record 43 of Set 4 | aksu
# Processing Record 44 of Set 4 | helensburgh
# Processing Record 45 of Set 4 | rio branco
# Processing Record 46 of Set 4 | kasempa
# Processing Record 47 of Set 4 | banepa
# Processing Record 48 of Set 4 | tessalit
# Processing Record 49 of Set 4 | veinticinco de mayo
# Processing Record 50 of Set 4 | moyale
# Processing Record 1 of Set 5 | norrtalje
# Processing Record 2 of Set 5 | tetouan
# Processing Record 3 of Set 5 | muisne
# Processing Record 4 of Set 5 | kruisfontein
# Processing Record 5 of Set 5 | ginda
# Processing Record 6 of Set 5 | malanje
# Processing Record 7 of Set 5 | pueblo rico
# Processing Record 8 of Set 5 | jaciara
# Processing Record 9 of Set 5 | vardo
# Processing Record 10 of Set 5 | kastamonu
# Processing Record 11 of Set 5 | komsomolskiy
# Processing Record 12 of Set 5 | sur
# Processing Record 13 of Set 5 | malaryta
# Processing Record 14 of Set 5 | jackson
# Processing Record 15 of Set 5 | corrente
# Processing Record 16 of Set 5 | conde
# Processing Record 17 of Set 5 | gualeguay
# Processing Record 18 of Set 5 | castro
# Processing Record 19 of Set 5 | llanes
# Processing Record 20 of Set 5 | oranjemund
# Processing Record 21 of Set 5 | geilo
# Processing Record 22 of Set 5 | margate
# Processing Record 23 of Set 5 | kosh-agach
# Processing Record 24 of Set 5 | marsh harbour
# Processing Record 25 of Set 5 | sikeston
# Processing Record 26 of Set 5 | kamina
# Processing Record 27 of Set 5 | raudeberg
# Processing Record 28 of Set 5 | manta
# Processing Record 29 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 5 | merritt island
# Processing Record 31 of Set 5 | quimper
# Processing Record 32 of Set 5 | goedereede
# Processing Record 33 of Set 5 | dolgorukovo
# Processing Record 34 of Set 5 | illela
# Processing Record 35 of Set 5 | arona
# Processing Record 36 of Set 5 | gambela
# Processing Record 37 of Set 5 | albany
# Processing Record 38 of Set 5 | sundumbili
# Processing Record 39 of Set 5 | san rafael
# Processing Record 40 of Set 5 | elizabeth city
# Processing Record 41 of Set 5 | beloha
# Processing Record 42 of Set 5 | malakal
# Processing Record 43 of Set 5 | bud
# Processing Record 44 of Set 5 | mozarlandia
# Processing Record 45 of Set 5 | zaysan
# Processing Record 46 of Set 5 | lircay
# Processing Record 47 of Set 5 | karpathos
# Processing Record 48 of Set 5 | hualmay
# Processing Record 49 of Set 5 | cayenne
# Processing Record 50 of Set 5 | ocala
# Processing Record 1 of Set 6 | aleksandro-nevskiy
# Processing Record 2 of Set 6 | tsogni
# Processing Record 3 of Set 6 | brae
# Processing Record 4 of Set 6 | peniche
# Processing Record 5 of Set 6 | caravelas
# Processing Record 6 of Set 6 | jacareacanga
# Processing Record 7 of Set 6 | husavik
# Processing Record 8 of Set 6 | naryan-mar
# Processing Record 9 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 6 | buritis
# Processing Record 11 of Set 6 | asuncion
# Processing Record 12 of Set 6 | luba
# Processing Record 13 of Set 6 | antsohihy
# Processing Record 14 of Set 6 | atar
# Processing Record 15 of Set 6 | voznesenye
# Processing Record 16 of Set 6 | xai-xai
# Processing Record 17 of Set 6 | kot diji
# Processing Record 18 of Set 6 | dondo
# Processing Record 19 of Set 6 | sao joao da barra
# Processing Record 20 of Set 6 | san ramon de la nueva oran
# Processing Record 21 of Set 6 | kuloy
# Processing Record 22 of Set 6 | nantucket
# Processing Record 23 of Set 6 | altamira
# Processing Record 24 of Set 6 | starotimoshkino
# Processing Record 25 of Set 6 | bakchar
# Processing Record 26 of Set 6 | santa helena
# Processing Record 27 of Set 6 | grand-lahou
# Processing Record 28 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 30 of Set 6 | ushtobe
# Processing Record 31 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 32 of Set 6 | harper
# Processing Record 33 of Set 6 | lagoa
# Processing Record 34 of Set 6 | eirunepe
# Processing Record 35 of Set 6 | greenfield
# Processing Record 36 of Set 6 | carauari
# Processing Record 37 of Set 6 | antalya
# Processing Record 38 of Set 6 | totma
# Processing Record 39 of Set 6 | kampene
# Processing Record 40 of Set 6 | yellamanchili
# City not found. Skipping...
# Processing Record 41 of Set 6 | los llanos de aridane
# Processing Record 42 of Set 6 | havelock
# Processing Record 43 of Set 6 | antalaha
# Processing Record 44 of Set 6 | lukiv
# Processing Record 45 of Set 6 | touros
# Processing Record 46 of Set 6 | soyo
# Processing Record 47 of Set 6 | murray
# Processing Record 48 of Set 6 | grand-santi
# Processing Record 49 of Set 6 | gondar
# Processing Record 50 of Set 6 | ubinskoye
# Processing Record 1 of Set 7 | kuytun
# Processing Record 2 of Set 7 | eden
# Processing Record 3 of Set 7 | esik
# Processing Record 4 of Set 7 | qasigiannguit
# Processing Record 5 of Set 7 | troitskoye
# Processing Record 6 of Set 7 | atasu
# Processing Record 7 of Set 7 | sao jose da coroa grande
# Processing Record 8 of Set 7 | chapais
# Processing Record 9 of Set 7 | trapani
# Processing Record 10 of Set 7 | bronnoysund
# Processing Record 11 of Set 7 | vila velha
# Processing Record 12 of Set 7 | chapada dos guimaraes
# Processing Record 13 of Set 7 | abu samrah
# Processing Record 14 of Set 7 | pangnirtung
# Processing Record 15 of Set 7 | saint-ambroise
# Processing Record 16 of Set 7 | isla mujeres
# Processing Record 17 of Set 7 | tatui
# Processing Record 18 of Set 7 | sekoma
# Processing Record 19 of Set 7 | coihaique
# Processing Record 20 of Set 7 | otjiwarongo
# Processing Record 21 of Set 7 | vilhena
# Processing Record 22 of Set 7 | cutervo
# Processing Record 23 of Set 7 | bubaque
# Processing Record 24 of Set 7 | bangui
# Processing Record 25 of Set 7 | korla
# Processing Record 26 of Set 7 | bosaso
# Processing Record 27 of Set 7 | buzmeyin
# Processing Record 28 of Set 7 | sorland
# Processing Record 29 of Set 7 | tiznit
# Processing Record 30 of Set 7 | hammerfest
# Processing Record 31 of Set 7 | bathsheba
# Processing Record 32 of Set 7 | kemijarvi
# Processing Record 33 of Set 7 | nampula
# Processing Record 34 of Set 7 | gazanjyk
# Processing Record 35 of Set 7 | goshen
# Processing Record 36 of Set 7 | meulaboh
# Processing Record 37 of Set 7 | yarovoye
# Processing Record 38 of Set 7 | tabuk
# Processing Record 39 of Set 7 | general roca
# Processing Record 40 of Set 7 | tucuma
# Processing Record 41 of Set 7 | dawlatabad
# Processing Record 42 of Set 7 | maiduguri
# Processing Record 43 of Set 7 | parrita
# Processing Record 44 of Set 7 | nkayi
# Processing Record 45 of Set 7 | george
# Processing Record 46 of Set 7 | lebu
# Processing Record 47 of Set 7 | ramasukha
# City not found. Skipping...
# Processing Record 48 of Set 7 | aktau
# Processing Record 49 of Set 7 | bengkulu
# Processing Record 50 of Set 7 | manavalakurichi
# Processing Record 1 of Set 8 | arenys de mar
# Processing Record 2 of Set 8 | herat
# Processing Record 3 of Set 8 | otuzco
# Processing Record 4 of Set 8 | mglin
# Processing Record 5 of Set 8 | le vauclin
# Processing Record 6 of Set 8 | mitu
# Processing Record 7 of Set 8 | sinnamary
# Processing Record 8 of Set 8 | mahibadhoo
# Processing Record 9 of Set 8 | parana
# Processing Record 10 of Set 8 | west bay
# Processing Record 11 of Set 8 | sao sebastiao
# Processing Record 12 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 8 | barcelona
# Processing Record 14 of Set 8 | kavaratti
# Processing Record 15 of Set 8 | birao
# Processing Record 16 of Set 8 | piracicaba
# Processing Record 17 of Set 8 | mumford
# Processing Record 18 of Set 8 | igrim
# Processing Record 19 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 8 | kachikau
# City not found. Skipping...
# Processing Record 21 of Set 8 | duz
# City not found. Skipping...
# Processing Record 22 of Set 8 | barcelos
# Processing Record 23 of Set 8 | alamor
# Processing Record 24 of Set 8 | uyemskiy
# Processing Record 25 of Set 8 | vazhiny
# Processing Record 26 of Set 8 | praia da vitoria
# Processing Record 27 of Set 8 | oneonta
# Processing Record 28 of Set 8 | lindi
# Processing Record 29 of Set 8 | pombas
# Processing Record 30 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 8 | abu dhabi
# Processing Record 32 of Set 8 | russkaya polyana
# Processing Record 33 of Set 8 | flums
# Processing Record 34 of Set 8 | mega
# Processing Record 35 of Set 8 | adiake
# Processing Record 36 of Set 8 | pitimbu
# Processing Record 37 of Set 8 | aktas
# Processing Record 38 of Set 8 | souillac
# Processing Record 39 of Set 8 | hambantota
# Processing Record 40 of Set 8 | belaguntha
# Processing Record 41 of Set 8 | leh
# Processing Record 42 of Set 8 | qaqortoq
# Processing Record 43 of Set 8 | abingdon
# Processing Record 44 of Set 8 | monrovia
# Processing Record 45 of Set 8 | wanlaweyn
# Processing Record 46 of Set 8 | gunjur
# Processing Record 47 of Set 8 | cururupu
# Processing Record 48 of Set 8 | fomboni
# Processing Record 49 of Set 8 | lienz
# Processing Record 50 of Set 8 | itupiranga
# Processing Record 1 of Set 9 | troitsko-pechorsk
# Processing Record 2 of Set 9 | boende
# Processing Record 3 of Set 9 | timizart
# Processing Record 4 of Set 9 | pinega
# Processing Record 5 of Set 9 | barmer
# Processing Record 6 of Set 9 | morant bay
# Processing Record 7 of Set 9 | oktyabrskoye
# Processing Record 8 of Set 9 | rocha
# Processing Record 9 of Set 9 | marawi
# Processing Record 10 of Set 9 | kempele
# Processing Record 11 of Set 9 | abnub
# Processing Record 12 of Set 9 | eydhafushi
# Processing Record 13 of Set 9 | la sarre
# Processing Record 14 of Set 9 | abrau-dyurso
# Processing Record 15 of Set 9 | gnjilane
# Processing Record 16 of Set 9 | camapua
# Processing Record 17 of Set 9 | sombrio
# Processing Record 18 of Set 9 | dmytrivka
# Processing Record 19 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 9 | asbe teferi
# Processing Record 21 of Set 9 | san ramon
# Processing Record 22 of Set 9 | kerman
# Processing Record 23 of Set 9 | bonfim
# Processing Record 24 of Set 9 | derzhavinsk
# Processing Record 25 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 9 | chahal
# Processing Record 27 of Set 9 | kambove
# Processing Record 28 of Set 9 | severodvinsk
# Processing Record 29 of Set 9 | debre birhan
# Processing Record 30 of Set 9 | manga
# Processing Record 31 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 32 of Set 9 | saint-joseph
# Processing Record 33 of Set 9 | cordoba
# Processing Record 34 of Set 9 | buraydah
# Processing Record 35 of Set 9 | adrar
# Processing Record 36 of Set 9 | balkhash
# Processing Record 37 of Set 9 | ancud
# Processing Record 38 of Set 9 | oussouye
# Processing Record 39 of Set 9 | maceio
# Processing Record 40 of Set 9 | talnakh
# Processing Record 41 of Set 9 | tansen
# Processing Record 42 of Set 9 | bloemfontein
# Processing Record 43 of Set 9 | san cristobal
# Processing Record 44 of Set 9 | pembroke
# Processing Record 45 of Set 9 | sabang
# Processing Record 46 of Set 9 | mangan
# Processing Record 47 of Set 9 | bermejo
# Processing Record 48 of Set 9 | inta
# Processing Record 49 of Set 9 | binga
# Processing Record 50 of Set 9 | woodstock
# Processing Record 1 of Set 10 | andarab
# City not found. Skipping...
# Processing Record 2 of Set 10 | usinsk
# Processing Record 3 of Set 10 | floresta
# Processing Record 4 of Set 10 | richards bay
# Processing Record 5 of Set 10 | la primavera
# Processing Record 6 of Set 10 | niagara falls
# Processing Record 7 of Set 10 | iquique
# Processing Record 8 of Set 10 | la rioja
# Processing Record 9 of Set 10 | grand gaube
# Processing Record 10 of Set 10 | gat
# Processing Record 11 of Set 10 | tenenkou
# Processing Record 12 of Set 10 | agucadoura
# Processing Record 13 of Set 10 | buchanan
# Processing Record 14 of Set 10 | yarim
# Processing Record 15 of Set 10 | alta floresta
# Processing Record 16 of Set 10 | wilmington
# Processing Record 17 of Set 10 | colares
# Processing Record 18 of Set 10 | arys
# Processing Record 19 of Set 10 | pueblo nuevo
# Processing Record 20 of Set 10 | el badari
# City not found. Skipping...
# Processing Record 21 of Set 10 | romitan
# Processing Record 22 of Set 10 | liverpool
# Processing Record 23 of Set 10 | suruc
# Processing Record 24 of Set 10 | koslan
# Processing Record 25 of Set 10 | zamora
# Processing Record 26 of Set 10 | bodden town
# Processing Record 27 of Set 10 | vila franca do campo
# Processing Record 28 of Set 10 | puerto del rosario
# Processing Record 29 of Set 10 | schattdorf
# Processing Record 30 of Set 10 | coswig
# Processing Record 31 of Set 10 | barranca
# Processing Record 32 of Set 10 | constitucion
# Processing Record 33 of Set 10 | natal
# Processing Record 34 of Set 10 | tambacounda
# Processing Record 35 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 36 of Set 10 | narasannapeta
# Processing Record 37 of Set 10 | atlantic city
# Processing Record 38 of Set 10 | mamallapuram
# Processing Record 39 of Set 10 | iranshahr
# Processing Record 40 of Set 10 | tubuala
# Processing Record 41 of Set 10 | cravo norte
# Processing Record 42 of Set 10 | kjopsvik
# Processing Record 43 of Set 10 | oltedal
# Processing Record 44 of Set 10 | dergachi
# Processing Record 45 of Set 10 | laguna
# Processing Record 46 of Set 10 | comodoro rivadavia
# Processing Record 47 of Set 10 | kebemer
# City not found. Skipping...
# Processing Record 48 of Set 10 | camacha
# Processing Record 49 of Set 10 | wattegama
# Processing Record 50 of Set 10 | sistranda
# Processing Record 1 of Set 11 | bogatyr
# Processing Record 2 of Set 11 | gouyave
# Processing Record 3 of Set 11 | ibimirim
# Processing Record 4 of Set 11 | male
# Processing Record 5 of Set 11 | san diego
# Processing Record 6 of Set 11 | kuusamo
# Processing Record 7 of Set 11 | vawkavysk
# Processing Record 8 of Set 11 | mercedes
# Processing Record 9 of Set 11 | morondava
# Processing Record 10 of Set 11 | guayaramerin
# Processing Record 11 of Set 11 | muridke
# Processing Record 12 of Set 11 | avigliana
# Processing Record 13 of Set 11 | lerwick
# Processing Record 14 of Set 11 | tutoia
# Processing Record 15 of Set 11 | guanica
# Processing Record 16 of Set 11 | montepuez
# Processing Record 17 of Set 11 | santa fe
# Processing Record 18 of Set 11 | umm lajj
# Processing Record 19 of Set 11 | manica
# Processing Record 20 of Set 11 | killybegs
# Processing Record 21 of Set 11 | lyaskelya
# Processing Record 22 of Set 11 | rio grande
# Processing Record 23 of Set 11 | bhadasar
# Processing Record 24 of Set 11 | karlshamn
# Processing Record 25 of Set 11 | ashta
# Processing Record 26 of Set 11 | shakawe
# Processing Record 27 of Set 11 | korampallam
# Processing Record 28 of Set 11 | bartica
# Processing Record 29 of Set 11 | gornopravdinsk
# Processing Record 30 of Set 11 | rudbar
# Processing Record 31 of Set 11 | isoka
# Processing Record 32 of Set 11 | sorkjosen
# Processing Record 33 of Set 11 | humaita
# Processing Record 34 of Set 11 | mangrol
# Processing Record 35 of Set 11 | kirkwall
# Processing Record 36 of Set 11 | matane
# Processing Record 37 of Set 11 | jumla
# Processing Record 38 of Set 11 | ampere
# Processing Record 39 of Set 11 | touba
# Processing Record 40 of Set 11 | gidam
# Processing Record 41 of Set 11 | choma
# Processing Record 42 of Set 11 | navirai
# Processing Record 43 of Set 11 | maridi
# Processing Record 44 of Set 11 | cucuta
# Processing Record 45 of Set 11 | charlestown
# Processing Record 46 of Set 11 | urumqi
# Processing Record 47 of Set 11 | viedma
# Processing Record 48 of Set 11 | marquette
# Processing Record 49 of Set 11 | negrar
# Processing Record 50 of Set 11 | mkushi
# Processing Record 1 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 12 | turtas
# Processing Record 3 of Set 12 | tabou
# Processing Record 4 of Set 12 | road town
# Processing Record 5 of Set 12 | ribas do rio pardo
# Processing Record 6 of Set 12 | suratgarh
# Processing Record 7 of Set 12 | somerset east
# Processing Record 8 of Set 12 | dakar
# Processing Record 9 of Set 12 | kattivakkam
# Processing Record 10 of Set 12 | sao miguel do araguaia
# Processing Record 11 of Set 12 | shiraz
# Processing Record 12 of Set 12 | nicoya
# Processing Record 13 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 14 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 12 | buffalo
# Processing Record 16 of Set 12 | bhadravati
# Processing Record 17 of Set 12 | treinta y tres
# Processing Record 18 of Set 12 | rawson
# Processing Record 19 of Set 12 | hirtshals
# Processing Record 20 of Set 12 | coquimbo
# Processing Record 21 of Set 12 | belen
# Processing Record 22 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 23 of Set 12 | nova esperanca
# Processing Record 24 of Set 12 | damietta
# Processing Record 25 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 26 of Set 12 | thinadhoo
# Processing Record 27 of Set 12 | la plata
# Processing Record 28 of Set 12 | anzhero-sudzhensk
# Processing Record 29 of Set 12 | barra da estiva
# Processing Record 30 of Set 12 | kedougou
# Processing Record 31 of Set 12 | arinos
# Processing Record 32 of Set 12 | stephenville
# Processing Record 33 of Set 12 | ramanathapuram
# Processing Record 34 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 12 | beziers
# Processing Record 36 of Set 12 | krasnoarmeysk
# Processing Record 37 of Set 12 | agirish
# Processing Record 38 of Set 12 | pitsunda
# Processing Record 39 of Set 12 | trindade
# Processing Record 40 of Set 12 | oksfjord
# Processing Record 41 of Set 12 | villaviciosa
# Processing Record 42 of Set 12 | koudougou
# Processing Record 43 of Set 12 | ambad
# Processing Record 44 of Set 12 | nador
# Processing Record 45 of Set 12 | pravokubanskiy
# Processing Record 46 of Set 12 | can
# Processing Record 47 of Set 12 | paita
# Processing Record 48 of Set 12 | ayagoz
# Processing Record 49 of Set 12 | mustasaari
# Processing Record 50 of Set 12 | chato
# Processing Record 1 of Set 13 | madaoua
# Processing Record 2 of Set 13 | salvador
# Processing Record 3 of Set 13 | boundiali
# Processing Record 4 of Set 13 | port elgin
# Processing Record 5 of Set 13 | rodrigues alves
# Processing Record 6 of Set 13 | praia
# Processing Record 7 of Set 13 | nalhati
# Processing Record 8 of Set 13 | dhidhdhoo
# Processing Record 9 of Set 13 | lahij
# Processing Record 10 of Set 13 | kita
# Processing Record 11 of Set 13 | abdanan
# Processing Record 12 of Set 13 | partyzany
# Processing Record 13 of Set 13 | olafsvik
# Processing Record 14 of Set 13 | krasnoselkup
# Processing Record 15 of Set 13 | callaway
# Processing Record 16 of Set 13 | dutlwe
# Processing Record 17 of Set 13 | lubango
# Processing Record 18 of Set 13 | santa isabel
# Processing Record 19 of Set 13 | sabla
# Processing Record 20 of Set 13 | salinopolis
# Processing Record 21 of Set 13 | la dolorita
# Processing Record 22 of Set 13 | stepnogorsk
# Processing Record 23 of Set 13 | henties bay
# Processing Record 24 of Set 13 | san lawrenz
# Processing Record 25 of Set 13 | sabha
# Processing Record 26 of Set 13 | zyrardow
# Processing Record 27 of Set 13 | oistins
# Processing Record 28 of Set 13 | kalamare
# Processing Record 29 of Set 13 | yei
# Processing Record 30 of Set 13 | port-de-paix
# City not found. Skipping...
# Processing Record 31 of Set 13 | dennery
# Processing Record 32 of Set 13 | vincennes
# Processing Record 33 of Set 13 | sokoni
# Processing Record 34 of Set 13 | asyut
# Processing Record 35 of Set 13 | kibala
# Processing Record 36 of Set 13 | panjab
# Processing Record 37 of Set 13 | tartus
# Processing Record 38 of Set 13 | birjand
# Processing Record 39 of Set 13 | savelugu
# Processing Record 40 of Set 13 | beinamar
# Processing Record 41 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 13 | centerville
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a Pandas datafram
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country                 Date      Lat      Lng  Max Temp  \
# 0  Bambous Virieux      MU  2022-05-06 02:00:30 -20.3428  57.7575     75.45
# 1          Iqaluit      CA  2022-05-06 01:59:07  63.7506 -68.5145     13.73
# 2        Jamestown      US  2022-05-06 01:59:08  42.0970 -79.2353     54.52
# 3         Tsivilsk      RU  2022-05-06 02:01:14  55.8611  47.4664     31.21
# 4      Port Alfred      ZA  2022-05-06 01:58:51 -33.5906  26.8910     68.79
# 5     Ponta Do Sol      PT  2022-05-06 02:01:17  32.6667 -17.1000     63.72
# 6           Taltal      CL  2022-05-06 02:01:18 -25.4000 -70.4833     62.58
# 7          Requena      ES  2022-05-06 02:01:21  39.4883  -1.1004     46.53
# 8          Ushuaia      AR  2022-05-06 02:01:23 -54.8000 -68.3000     37.81
# 9      Honningsvag      NO  2022-05-06 02:01:24  70.9821  25.9704     37.15
#
#    Humidity  Cloudiness  Wind Speed
# 0        88          40       18.41
# 1        79          20       13.80
# 2        69         100        5.55
# 3        60           2        5.53
# 4        51           0       10.16
# 5        72         100        3.29
# 6        81         100        2.42
# 7        70           3        5.48
# 8        98          82       11.36
# 9        81         100       17.27

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
#Extract relevant fields from the DataFrame for plotting 
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
#Import
